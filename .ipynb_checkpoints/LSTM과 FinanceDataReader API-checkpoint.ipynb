# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
# https://teddylee777.github.io/tensorflow/lstm-stock-forecast
# LSTM과 FinanceDataReader API를 활용한 삼성전자 주가 예측

# %%
# 삼성전자(005930) 전체 (1996-11-05 ~ 현재)
samsung = fdr.DataReader('005930')

# %%
samsung.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-04-05  85800  86000  84800  85400  16255990  0.007075
# 2021-04-06  86200  86200  85100  86000  19042023  0.007026
# 2021-04-07  86100  86200  85400  85600  17885538 -0.004651
# 2021-04-08  85700  85700  84100  84700  19244259 -0.010514
# 2021-04-09  84700  84900  83600  83700   9451141 -0.011806

# %%
# 삼성전자 주식코드: 005930
STOCK_CODE = '005930'
stock = fdr.DataReader(STOCK_CODE)

# %%
stock.head()
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 1997-04-16  1095  1102  1084   1101  127780       NaN
# 1997-04-17  1093  1099  1072   1085  122360 -0.014532
# 1997-04-18  1090  1097  1058   1071   98810 -0.012903
# 1997-04-19  1076  1109  1076   1110   48690  0.036415
# 1997-04-21  1111  1118  1093   1094   76890 -0.014414

# %%
stock.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-04-05  85800  86000  84800  85400  16255990  0.007075
# 2021-04-06  86200  86200  85100  86000  19042023  0.007026
# 2021-04-07  86100  86200  85400  85600  17885538 -0.004651
# 2021-04-08  85700  85700  84100  84700  19244259 -0.010514
# 2021-04-09  84700  84900  83600  83700   9451141 -0.011806

# %%
stock.index
# Out:
# DatetimeIndex(['1997-04-16', '1997-04-17', '1997-04-18', '1997-04-19',
#                '1997-04-21', '1997-04-22', '1997-04-23', '1997-04-24',
#                '1997-04-25', '1997-04-26',
#                ...
#                '2021-03-29', '2021-03-30', '2021-03-31', '2021-04-01',
#                '2021-04-02', '2021-04-05', '2021-04-06', '2021-04-07',
#                '2021-04-08', '2021-04-09'],
#               dtype='datetime64[ns]', name='Date', length=6000, freq=None)

# %%
stock['Year'] = stock.index.year
stock['Month'] = stock.index.month
stock['Day'] = stock.index.day

# %%
stock.head()
# Out:
#             Open  High   Low  Close  Volume    Change  Year  Month  Day
# Date
# 1997-04-16  1095  1102  1084   1101  127780       NaN  1997      4   16
# 1997-04-17  1093  1099  1072   1085  122360 -0.014532  1997      4   17
# 1997-04-18  1090  1097  1058   1071   98810 -0.012903  1997      4   18
# 1997-04-19  1076  1109  1076   1110   48690  0.036415  1997      4   19
# 1997-04-21  1111  1118  1093   1094   76890 -0.014414  1997      4   21

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(y=stock['Close'], x=stock.index)
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
time_steps = [['1990', '2000'], 
              ['2000', '2010'], 
              ['2010', '2015'], 
              ['2015', '2020']]

fig, axes = plt.subplots(2, 2)
fig.set_size_inches(16, 9)
for i in range(4):
    ax = axes[i//2, i%2]
    df = stock.loc[(stock.index > time_steps[i][0]) & (stock.index < time_steps[i][1])]
    sns.lineplot(y=df['Close'], x=df.index, ax=ax)
    ax.set_title(f'{time_steps[i][0]}~{time_steps[i][1]}')
    ax.set_xlabel('time')
    ax.set_ylabel('price')
plt.tight_layout()
plt.show()

# %%
stock['Close'][20:] = stock['Close'][:-20]
stock = stock[20:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# 스케일을 적용할 column을 정의합니다.
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
# 스케일 후 columns
scaled = scaler.fit_transform(stock[scale_cols])
scaled
# Out:
# array([[1.19269103e-02, 1.13119835e-02, 1.19329609e-02, 5.24492935e-03,
#         1.17422754e-03],
#        [1.20265781e-02, 1.13533058e-02, 1.19553073e-02, 5.06788532e-03,
#         8.38480849e-04],
#        [1.22037652e-02, 1.17871901e-02, 1.22905028e-02, 4.91297179e-03,
#         2.08490722e-03],
#        ...,
#        [9.53488372e-01, 8.90495868e-01, 9.54189944e-01, 8.88240957e-01,
#         1.98054425e-01],
#        [9.49058693e-01, 8.85330579e-01, 9.39664804e-01, 9.00412734e-01,
#         2.13100140e-01],
#        [9.37984496e-01, 8.77066116e-01, 9.34078212e-01, 9.09264935e-01,
#         1.04656639e-01]])

# %%
df = pd.DataFrame(scaled, columns=scale_cols)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Close', 1), df['Close'], test_size=0.2, random_state=0, shuffle=False)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((4784, 4), (4784,), (1196, 4), (1196,))

# %%
x_train
# Out:
#           Open      High       Low    Volume
# 0     0.011927  0.011312  0.011933  0.001174
# 1     0.012027  0.011353  0.011955  0.000838
# 2     0.012204  0.011787  0.012291  0.002085
# 3     0.012503  0.011756  0.012480  0.001865
# 4     0.012425  0.011663  0.012313  0.000630
# ...        ...       ...       ...       ...
# 4779  0.281063  0.265702  0.283575  0.001797
# 4780  0.284828  0.266322  0.283352  0.002311
# 4781  0.284164  0.268182  0.284693  0.002627
# 4782  0.287708  0.269215  0.289385  0.002802
# 4783  0.287929  0.268802  0.284469  0.003044
#
# [4784 rows x 4 columns]

# %%
import tensorflow as tf
import numpy as np

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=20
BATCH_SIZE=32

# %%
# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
# 아래의 코드로 데이터셋의 구성을 확인해 볼 수 있습니다.
# X: (batch_size, window_size, feature)
# Y: (batch_size, feature)
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (32, 20, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (32, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[WINDOW_SIZE, 1]),
    # LSTM
    LSTM(16, activation='tanh'),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
# val_loss 기준 체크포인터도 생성합니다.
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
history = model.fit(train_data, 
                    validation_data=(test_data), 
                    epochs=50, 
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
#     145/Unknown - 0s 2ms/step - loss: 1.0059e-04 - mse: 2.0117e-04
# Epoch 00001: val_loss improved from inf to 0.00094, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 9ms/step - loss: 9.8935e-05 - mse: 1.9787e-04 - val_loss: 9.3889e-04 - val_mse: 0.0019
# Epoch 2/50
# 144/149 [===========================>..] - ETA: 0s - loss: 1.9168e-05 - mse: 3.8336e-05
# Epoch 00002: val_loss did not improve from 0.00094
# 149/149 [==============================] - 0s 3ms/step - loss: 1.9742e-05 - mse: 3.9484e-05 - val_loss: 9.8128e-04 - val_mse: 0.0020
# Epoch 3/50
# 143/149 [===========================>..] - ETA: 0s - loss: 1.9559e-05 - mse: 3.9119e-05
# Epoch 00003: val_loss did not improve from 0.00094
# 149/149 [==============================] - 0s 3ms/step - loss: 1.9977e-05 - mse: 3.9955e-05 - val_loss: 0.0012 - val_mse: 0.0023
# Epoch 4/50
# 148/149 [============================>.] - ETA: 0s - loss: 1.8736e-05 - mse: 3.7472e-05
# Epoch 00004: val_loss did not improve from 0.00094
# 149/149 [==============================] - 0s 3ms/step - loss: 1.8799e-05 - mse: 3.7597e-05 - val_loss: 0.0012 - val_mse: 0.0024
# Epoch 5/50
# 147/149 [============================>.] - ETA: 0s - loss: 1.8155e-05 - mse: 3.6309e-05
# Epoch 00005: val_loss improved from 0.00094 to 0.00065, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 5ms/step - loss: 1.8404e-05 - mse: 3.6807e-05 - val_loss: 6.5244e-04 - val_mse: 0.0013
# Epoch 6/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.7320e-05 - mse: 3.4641e-05
# Epoch 00006: val_loss improved from 0.00065 to 0.00054, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 5ms/step - loss: 1.7532e-05 - mse: 3.5063e-05 - val_loss: 5.3682e-04 - val_mse: 0.0011
# Epoch 7/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.6644e-05 - mse: 3.3287e-05
# Epoch 00007: val_loss did not improve from 0.00054
# 149/149 [==============================] - 0s 3ms/step - loss: 1.7112e-05 - mse: 3.4224e-05 - val_loss: 5.6109e-04 - val_mse: 0.0011
# Epoch 8/50
# 143/149 [===========================>..] - ETA: 0s - loss: 1.5329e-05 - mse: 3.0657e-05
# Epoch 00008: val_loss improved from 0.00054 to 0.00045, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 1.5700e-05 - mse: 3.1401e-05 - val_loss: 4.5013e-04 - val_mse: 9.0027e-04
# Epoch 9/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.5610e-05 - mse: 3.1221e-05
# Epoch 00009: val_loss did not improve from 0.00045
# 149/149 [==============================] - 0s 3ms/step - loss: 1.5790e-05 - mse: 3.1581e-05 - val_loss: 4.7575e-04 - val_mse: 9.5149e-04
# Epoch 10/50
# 147/149 [============================>.] - ETA: 0s - loss: 1.5104e-05 - mse: 3.0208e-05
# Epoch 00010: val_loss did not improve from 0.00045
# 149/149 [==============================] - 0s 3ms/step - loss: 1.5161e-05 - mse: 3.0322e-05 - val_loss: 4.7565e-04 - val_mse: 9.5130e-04
# Epoch 11/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.3928e-05 - mse: 2.7857e-05
# Epoch 00011: val_loss improved from 0.00045 to 0.00042, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 1.4136e-05 - mse: 2.8272e-05 - val_loss: 4.1639e-04 - val_mse: 8.3279e-04
# Epoch 12/50
# 143/149 [===========================>..] - ETA: 0s - loss: 1.4380e-05 - mse: 2.8760e-05
# Epoch 00012: val_loss did not improve from 0.00042
# 149/149 [==============================] - 0s 3ms/step - loss: 1.4638e-05 - mse: 2.9275e-05 - val_loss: 4.6943e-04 - val_mse: 9.3887e-04
# Epoch 13/50
# 146/149 [============================>.] - ETA: 0s - loss: 1.3499e-05 - mse: 2.6998e-05
# Epoch 00013: val_loss improved from 0.00042 to 0.00037, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 1.3770e-05 - mse: 2.7540e-05 - val_loss: 3.7265e-04 - val_mse: 7.4529e-04
# Epoch 14/50
# 143/149 [===========================>..] - ETA: 0s - loss: 1.3326e-05 - mse: 2.6653e-05
# Epoch 00014: val_loss improved from 0.00037 to 0.00021, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 1.3723e-05 - mse: 2.7447e-05 - val_loss: 2.1014e-04 - val_mse: 4.2028e-04
# Epoch 15/50
# 147/149 [============================>.] - ETA: 0s - loss: 1.2342e-05 - mse: 2.4684e-05
# Epoch 00015: val_loss did not improve from 0.00021
# 149/149 [==============================] - 0s 3ms/step - loss: 1.2486e-05 - mse: 2.4973e-05 - val_loss: 2.7372e-04 - val_mse: 5.4743e-04
# Epoch 16/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.1587e-05 - mse: 2.3175e-05
# Epoch 00016: val_loss improved from 0.00021 to 0.00021, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 5ms/step - loss: 1.1949e-05 - mse: 2.3897e-05 - val_loss: 2.0525e-04 - val_mse: 4.1049e-04
# Epoch 17/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.2245e-05 - mse: 2.4490e-05
# Epoch 00017: val_loss did not improve from 0.00021
# 149/149 [==============================] - 0s 3ms/step - loss: 1.2415e-05 - mse: 2.4830e-05 - val_loss: 2.0838e-04 - val_mse: 4.1676e-04
# Epoch 18/50
# 146/149 [============================>.] - ETA: 0s - loss: 1.1450e-05 - mse: 2.2900e-05
# Epoch 00018: val_loss did not improve from 0.00021
# 149/149 [==============================] - 0s 3ms/step - loss: 1.1721e-05 - mse: 2.3442e-05 - val_loss: 2.3058e-04 - val_mse: 4.6115e-04
# Epoch 19/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.0833e-05 - mse: 2.1667e-05
# Epoch 00019: val_loss improved from 0.00021 to 0.00015, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 1.1033e-05 - mse: 2.2065e-05 - val_loss: 1.5452e-04 - val_mse: 3.0904e-04
# Epoch 20/50
# 148/149 [============================>.] - ETA: 0s - loss: 1.1353e-05 - mse: 2.2707e-05
# Epoch 00020: val_loss improved from 0.00015 to 0.00013, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 1.1378e-05 - mse: 2.2755e-05 - val_loss: 1.2968e-04 - val_mse: 2.5937e-04
# Epoch 21/50
# 145/149 [============================>.] - ETA: 0s - loss: 1.0276e-05 - mse: 2.0552e-05
# Epoch 00021: val_loss did not improve from 0.00013
# 149/149 [==============================] - 0s 3ms/step - loss: 1.0506e-05 - mse: 2.1013e-05 - val_loss: 1.5285e-04 - val_mse: 3.0570e-04
# Epoch 22/50
# 143/149 [===========================>..] - ETA: 0s - loss: 1.1021e-05 - mse: 2.2042e-05
# Epoch 00022: val_loss improved from 0.00013 to 0.00012, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 1.1298e-05 - mse: 2.2595e-05 - val_loss: 1.2042e-04 - val_mse: 2.4084e-04
# Epoch 23/50
# 146/149 [============================>.] - ETA: 0s - loss: 1.1543e-05 - mse: 2.3086e-05
# Epoch 00023: val_loss did not improve from 0.00012
# 149/149 [==============================] - 0s 3ms/step - loss: 1.1591e-05 - mse: 2.3181e-05 - val_loss: 1.3467e-04 - val_mse: 2.6933e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 1.0581e-05 - mse: 2.1162e-05
# Epoch 00024: val_loss did not improve from 0.00012
# 149/149 [==============================] - 0s 3ms/step - loss: 1.0581e-05 - mse: 2.1162e-05 - val_loss: 1.4507e-04 - val_mse: 2.9015e-04
# Epoch 25/50
# 147/149 [============================>.] - ETA: 0s - loss: 9.8823e-06 - mse: 1.9765e-05
# Epoch 00025: val_loss did not improve from 0.00012
# 149/149 [==============================] - 0s 3ms/step - loss: 9.9747e-06 - mse: 1.9949e-05 - val_loss: 1.3026e-04 - val_mse: 2.6051e-04
# Epoch 26/50
# 137/149 [==========================>...] - ETA: 0s - loss: 9.1937e-06 - mse: 1.8387e-05
# Epoch 00026: val_loss improved from 0.00012 to 0.00011, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 5ms/step - loss: 1.0091e-05 - mse: 2.0181e-05 - val_loss: 1.0641e-04 - val_mse: 2.1282e-04
# Epoch 27/50
# 149/149 [==============================] - ETA: 0s - loss: 9.5607e-06 - mse: 1.9121e-05
# Epoch 00027: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 9.5607e-06 - mse: 1.9121e-05 - val_loss: 1.7408e-04 - val_mse: 3.4816e-04
# Epoch 28/50
# 149/149 [==============================] - ETA: 0s - loss: 1.0007e-05 - mse: 2.0014e-05
# Epoch 00028: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 1.0007e-05 - mse: 2.0014e-05 - val_loss: 1.3318e-04 - val_mse: 2.6636e-04
# Epoch 29/50
# 147/149 [============================>.] - ETA: 0s - loss: 1.0058e-05 - mse: 2.0117e-05
# Epoch 00029: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 1.0177e-05 - mse: 2.0355e-05 - val_loss: 1.4781e-04 - val_mse: 2.9563e-04
# Epoch 30/50
# 149/149 [==============================] - ETA: 0s - loss: 9.8574e-06 - mse: 1.9715e-05
# Epoch 00030: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 9.8574e-06 - mse: 1.9715e-05 - val_loss: 1.7872e-04 - val_mse: 3.5745e-04
# Epoch 31/50
# 145/149 [============================>.] - ETA: 0s - loss: 9.2020e-06 - mse: 1.8404e-05
# Epoch 00031: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 9.3162e-06 - mse: 1.8632e-05 - val_loss: 2.4423e-04 - val_mse: 4.8847e-04
# Epoch 32/50
# 148/149 [============================>.] - ETA: 0s - loss: 9.5697e-06 - mse: 1.9139e-05
# Epoch 00032: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 9.6321e-06 - mse: 1.9264e-05 - val_loss: 1.6473e-04 - val_mse: 3.2946e-04
# Epoch 33/50
# 139/149 [==========================>...] - ETA: 0s - loss: 9.3295e-06 - mse: 1.8659e-05
# Epoch 00033: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 9.7957e-06 - mse: 1.9591e-05 - val_loss: 1.4270e-04 - val_mse: 2.8540e-04
# Epoch 34/50
# 146/149 [============================>.] - ETA: 0s - loss: 9.4364e-06 - mse: 1.8873e-05
# Epoch 00034: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 9.5512e-06 - mse: 1.9102e-05 - val_loss: 1.0911e-04 - val_mse: 2.1823e-04
# Epoch 35/50
# 144/149 [===========================>..] - ETA: 0s - loss: 8.4097e-06 - mse: 1.6819e-05
# Epoch 00035: val_loss did not improve from 0.00011
# 149/149 [==============================] - 0s 3ms/step - loss: 8.6299e-06 - mse: 1.7260e-05 - val_loss: 1.2692e-04 - val_mse: 2.5383e-04
# Epoch 36/50
# 148/149 [============================>.] - ETA: 0s - loss: 8.6274e-06 - mse: 1.7255e-05
# Epoch 00036: val_loss improved from 0.00011 to 0.00010, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 5ms/step - loss: 8.6691e-06 - mse: 1.7338e-05 - val_loss: 9.9287e-05 - val_mse: 1.9857e-04
# Epoch 37/50
# 144/149 [===========================>..] - ETA: 0s - loss: 8.6433e-06 - mse: 1.7287e-05
# Epoch 00037: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 8.8521e-06 - mse: 1.7704e-05 - val_loss: 1.3463e-04 - val_mse: 2.6925e-04
# Epoch 38/50
# 145/149 [============================>.] - ETA: 0s - loss: 8.9733e-06 - mse: 1.7947e-05
# Epoch 00038: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 9.0709e-06 - mse: 1.8142e-05 - val_loss: 1.8488e-04 - val_mse: 3.6976e-04
# Epoch 39/50
# 146/149 [============================>.] - ETA: 0s - loss: 9.4053e-06 - mse: 1.8811e-05
# Epoch 00039: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 9.6755e-06 - mse: 1.9351e-05 - val_loss: 2.5300e-04 - val_mse: 5.0600e-04
# Epoch 40/50
# 145/149 [============================>.] - ETA: 0s - loss: 9.2050e-06 - mse: 1.8410e-05
# Epoch 00040: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 9.4350e-06 - mse: 1.8870e-05 - val_loss: 1.0270e-04 - val_mse: 2.0540e-04
# Epoch 41/50
# 148/149 [============================>.] - ETA: 0s - loss: 8.8571e-06 - mse: 1.7714e-05
# Epoch 00041: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 8.9759e-06 - mse: 1.7952e-05 - val_loss: 1.0751e-04 - val_mse: 2.1503e-04
# Epoch 42/50
# 140/149 [===========================>..] - ETA: 0s - loss: 8.0107e-06 - mse: 1.6021e-05
# Epoch 00042: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 8.5154e-06 - mse: 1.7031e-05 - val_loss: 1.0931e-04 - val_mse: 2.1862e-04
# Epoch 43/50
# 133/149 [=========================>....] - ETA: 0s - loss: 8.7633e-06 - mse: 1.7527e-05
# Epoch 00043: val_loss improved from 0.00010 to 0.00010, saving model to tmp\ckeckpointer.ckpt
# 149/149 [==============================] - 1s 6ms/step - loss: 9.2397e-06 - mse: 1.8479e-05 - val_loss: 9.8142e-05 - val_mse: 1.9628e-04
# Epoch 44/50
# 149/149 [==============================] - ETA: 0s - loss: 8.3511e-06 - mse: 1.6702e-05
# Epoch 00044: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 8.3511e-06 - mse: 1.6702e-05 - val_loss: 1.9447e-04 - val_mse: 3.8894e-04
# Epoch 45/50
# 147/149 [============================>.] - ETA: 0s - loss: 8.5510e-06 - mse: 1.7102e-05
# Epoch 00045: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 8.6393e-06 - mse: 1.7279e-05 - val_loss: 1.2784e-04 - val_mse: 2.5568e-04
# Epoch 46/50
# 149/149 [==============================] - ETA: 0s - loss: 8.3064e-06 - mse: 1.6613e-05
# Epoch 00046: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 8.3064e-06 - mse: 1.6613e-05 - val_loss: 1.6392e-04 - val_mse: 3.2784e-04
# Epoch 47/50
# 146/149 [============================>.] - ETA: 0s - loss: 7.6891e-06 - mse: 1.5378e-05
# Epoch 00047: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 7.8979e-06 - mse: 1.5796e-05 - val_loss: 1.4405e-04 - val_mse: 2.8810e-04
# Epoch 48/50
# 145/149 [============================>.] - ETA: 0s - loss: 8.2636e-06 - mse: 1.6527e-05
# Epoch 00048: val_loss did not improve from 0.00010
# 149/149 [==============================] - 1s 3ms/step - loss: 8.4261e-06 - mse: 1.6852e-05 - val_loss: 1.4557e-04 - val_mse: 2.9114e-04
# Epoch 49/50
# 146/149 [============================>.] - ETA: 0s - loss: 7.8977e-06 - mse: 1.5795e-05
# Epoch 00049: val_loss did not improve from 0.00010
# 149/149 [==============================] - 0s 3ms/step - loss: 8.1514e-06 - mse: 1.6303e-05 - val_loss: 1.4733e-04 - val_mse: 2.9466e-04
# Epoch 50/50
# 135/149 [==========================>...] - ETA: 0s - loss: 7.4202e-06 - mse: 1.4840e-05
# Epoch 00050: val_loss did not improve from 0.00010
# 149/149 [==============================] - 1s 3ms/step - loss: 8.1787e-06 - mse: 1.6357e-05 - val_loss: 1.8816e-04 - val_mse: 3.7633e-04

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_data)

# %%
pred.shape
# Out:
# (1176, 1)

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.asarray(y_test)[20:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
x_test
# Out:
#           Open      High       Low    Volume
# 4784  0.287265  0.267975  0.284693  0.002285
# 4785  0.283499  0.268595  0.283352  0.013848
# 4786  0.287486  0.277066  0.289385  0.005205
# 4787  0.299003  0.283471  0.300782  0.005272
# 4788  0.303433  0.284917  0.304804  0.003780
# ...        ...       ...       ...       ...
# 5975  0.950166  0.888430  0.947486  0.180010
# 5976  0.954596  0.890496  0.950838  0.210861
# 5977  0.953488  0.890496  0.954190  0.198054
# 5978  0.949059  0.885331  0.939665  0.213100
# 5979  0.937984  0.877066  0.934078  0.104657
#
# [1196 rows x 4 columns]

# %%
y_test, len(y_test)
# Out:
# (4784    0.273013
#  4785    0.268587
#  4786    0.269693
#  4787    0.272128
#  4788    0.278546
#            ...
#  5975    0.900413
#  5976    0.893774
#  5977    0.888241
#  5978    0.900413
#  5979    0.909265
#  Name: Close, Length: 1196, dtype: float64,
#  1196)

# %%
p = fdr.DataReader('011200')

# %%
stock = p[len(p)-1200:]
# stock['Close'][20:] = stock['Close'][:-20]
# stock = stock[20:]

# %%
scaler = MinMaxScaler()
# 스케일을 적용할 column을 정의합니다.
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
# 스케일 후 columns
scaled = scaler.fit_transform(stock[scale_cols])
scaled
df = pd.DataFrame(scaled, columns=scale_cols)
y_train, y_test = df.drop('Close', 1), df['Close']

# %%
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
for data in test_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, wddindow_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, wddindow_size, feature갯수): (32, 20, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (32, 1)

# %%
pred = model.predict(test_data)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.asarray(y_test)[20:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
stock = pd.read_csv('삼성전자테스트분봉.csv')
stock
# Out:
#          종목                       시간     시가     고가     저가     종가     거래량  \
# 0      5930  2021-04-05 15:30:00.000  85400  85400  85400  85400  474185
# 1      5930  2021-04-05 15:20:00.000  85400  85500  85300  85400   90715
# 2      5930  2021-04-05 15:19:00.000  85400  85400  85300  85400   28199
# 3      5930  2021-04-05 15:18:00.000  85400  85400  85300  85400   46867
# 4      5930  2021-04-05 15:17:00.000  85300  85400  85300  85400   25800
# ...     ...                      ...    ...    ...    ...    ...     ...
# 19995  5930  2021-01-18 12:18:00.000  86700  86800  86700  86700   14869
# 19996  5930  2021-01-18 12:17:00.000  86700  86800  86700  86800   23125
# 19997  5930  2021-01-18 12:16:00.000  86800  86800  86700  86700   15816
# 19998  5930  2021-01-18 12:15:00.000  86800  86800  86700  86700   12363
# 19999  5930  2021-01-18 12:14:00.000  86700  86800  86700  86700   23159
#
#               거래대금  미결제약정수량
# 0      40495398912        0
# 1       7746277888        0
# 2       2407886592        0
# 3       4002255872        0
# 4       2203006720        0
# ...            ...      ...
# 19995   1289388160        0
# 19996   2006268160        0
# 19997   1371436288        0
# 19998   1072048128        0
# 19999   2008137344        0
#
# [20000 rows x 9 columns]

# %%
scaler = MinMaxScaler()
# 스케일을 적용할 column을 정의합니다.
scale_cols = ['시가', '고가', '저가', '종가', '거래량']
# 스케일 후 columns
scaled = scaler.fit_transform(stock[scale_cols])
scaled
df = pd.DataFrame(scaled, columns=scale_cols)
y_train, y_test = df.drop('종가', 1), df['종가']
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)
pred = model.predict(test_data)

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.asarray(y_test)[20:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()
