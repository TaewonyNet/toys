# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import FinanceDataReader as fdr
import datetime
# %matplotlib inline
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
plt.rcParams["figure.figsize"] = (14,10) #그림(figure)의 크기. (가로,세로) 인치 단위
plt.rcParams['lines.linewidth'] = 2 #선의 두께
# plt.rcParams['lines.color'] = 'r' #선의 색깔
plt.rcParams['axes.grid'] = True #차트내 격자선(grid) 표시 여부

# %%
kospi = fdr.DataReader('KS11', '2015')
dft = kospi[-1000:]
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
dft = kospi[-1000:]
n = 20
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
# Out:
# <ipython-input-3-a9fb52b8e08e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-3-a9fb52b8e08e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# <ipython-input-3-a9fb52b8e08e>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-3-a9fb52b8e08e>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dji = fdr.DataReader('DJI', '2015')
dft = dji[-1000:]
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
dft = dji[-1000:]
n = 20
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
# Out:
# <ipython-input-33-92f2df50d67a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-33-92f2df50d67a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# <ipython-input-33-92f2df50d67a>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-33-92f2df50d67a>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
snp = fdr.DataReader('US500', '2015')
dft = snp[-1000:]
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
dft = snp[-1000:]
n = 20
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
# Out:
# <ipython-input-34-80073f722ab7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-34-80073f722ab7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# <ipython-input-34-80073f722ab7>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-34-80073f722ab7>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Out:
#               Close     Open     High      Low  Volume  Change  ndays_high  \
# Date
# 2017-10-17  2559.36  2557.17  2559.71  2554.69     0.0  0.0007     2559.71
# 2017-10-18  2561.26  2562.87  2564.11  2559.67     0.0  0.0007     2564.11
# 2017-10-19  2562.10  2553.39  2562.36  2547.92     0.0  0.0003     2564.11
# 2017-10-20  2575.21  2567.56  2575.44  2567.56     0.0  0.0051     2575.44
# 2017-10-23  2564.98  2578.08  2578.29  2564.33     0.0 -0.0040     2578.29
# ...             ...      ...      ...      ...     ...     ...         ...
# 2021-09-30  4307.54  4370.67  4382.55  4306.24     0.0 -0.0119     4545.85
# 2021-10-01  4357.05  4317.16  4375.19  4288.52     0.0  0.0115     4545.85
# 2021-10-04  4300.46  4348.84  4355.51  4278.94     0.0 -0.0130     4545.85
# 2021-10-05  4345.72  4309.87  4369.23  4309.87     0.0  0.0105     4545.85
# 2021-10-06  4363.55  4319.57  4365.57  4290.49     0.0  0.0041     4545.85
#
#             ndays_low
# Date
# 2017-10-17    2554.69
# 2017-10-18    2554.69
# 2017-10-19    2547.92
# 2017-10-20    2547.92
# 2017-10-23    2547.92
# ...               ...
# 2021-09-30    4305.91
# 2021-10-01    4288.52
# 2021-10-04    4278.94
# 2021-10-05    4278.94
# 2021-10-06    4278.94
#
# [1000 rows x 8 columns]

# %%
dji = fdr.DataReader('DJI', '2015')
dft = dji[-1000:]
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
dft = dji[-1000:]
n = 20
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
# Out:
# <ipython-input-5-2e52d053858f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-5-2e52d053858f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# <ipython-input-5-2e52d053858f>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-5-2e52d053858f>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()

# %%
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
# Out:
# <ipython-input-6-d1435844fbd4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-6-d1435844fbd4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()

# %%
from prophet import Prophet
dft = dji
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'
# 995                         0.0  4460.168654
# 996                         0.0  4462.826139
# 997                         0.0  4464.918169
# 998                         0.0  4470.823842
# 999                         0.0  4471.347098
#
# [1000 rows x 19 columns]

# %%
from prophet import Prophet
def run_prophet(timeserie):
    model = Prophet(yearly_seasonality=False,daily_seasonality=False)
    model.fit(timeserie)
    forecast = model.make_future_dataframe(periods=90, include_history=False)
    forecast = model.predict(forecast)
    return forecast

# %%
dfhl
# Out:
#             ds    Close  ndays_high        y
# 0   2017-10-17  2559.36     2559.71  2554.69
# 1   2017-10-18  2561.26     2564.11  2554.69
# 2   2017-10-19  2562.10     2564.11  2547.92
# 3   2017-10-20  2575.21     2575.44  2547.92
# 4   2017-10-23  2564.98     2578.29  2547.92
# ..         ...      ...         ...      ...
# 995 2021-09-30  4307.54     4545.85  4305.91
# 996 2021-10-01  4357.05     4545.85  4288.52
# 997 2021-10-04  4300.46     4545.85  4278.94
# 998 2021-10-05  4345.72     4545.85  4278.94
# 999 2021-10-06  4363.55     4545.85  4278.94
#
# [1000 rows x 4 columns]

# %%
mc.predict

# %%
from multiprocessing import Pool, cpu_count
from tqdm import tqdm
p = Pool(cpu_count())
predictions = list(tqdm(p.imap(run_prophet, dfhl), total=len(dfhl)))
p.close()
p.join()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#   0%|                                                                                         | 0/1000 [00:00<?, ?it/s]

# %%
Prophet.make_future_dataframe(periods=14)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-65c3cbef33ad> in <module>
# ----> 1 Prophet.make_future_dataframe(periods=14)
#
# TypeError: make_future_dataframe() missing 1 required positional argument: 'self'

# %%
dfh = pd.DataFrame(dfhl, columns=['ds', 'y'])

# %%
dfh
# Out:
#             ds        y
# 0   2017-10-17  2554.69
# 1   2017-10-18  2554.69
# 2   2017-10-19  2547.92
# 3   2017-10-20  2547.92
# 4   2017-10-23  2547.92
# ..         ...      ...
# 995 2021-09-30  4305.91
# 996 2021-10-01  4288.52
# 997 2021-10-04  4278.94
# 998 2021-10-05  4278.94
# 999 2021-10-06  4278.94
#
# [1000 rows x 2 columns]

# %%
mc.predict(dfh)
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   2017-10-17  2639.048443  2500.805183  2675.668118  2639.048443
# 1   2017-10-18  2639.557423  2502.337279  2681.469375  2639.557423
# 2   2017-10-19  2640.066402  2500.916006  2670.313134  2640.066402
# 3   2017-10-20  2640.575382  2501.416275  2676.450980  2640.575382
# 4   2017-10-23  2642.102322  2493.756476  2662.157501  2642.102322
# ..         ...          ...          ...          ...          ...
# 995 2021-09-30  4487.785343  4377.823091  4546.100708  4487.785343
# 996 2021-10-01  4490.562222  4376.376248  4549.747737  4490.562222
# 997 2021-10-04  4498.892859  4381.517563  4559.572157  4498.892859
# 998 2021-10-05  4501.669738  4380.993708  4560.734924  4501.669738
# 999 2021-10-06  4504.446617  4384.931522  4559.502858  4504.446617
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    2639.048443      -47.465765            -47.465765            -47.465765
# 1    2639.557423      -50.886612            -50.886612            -50.886612
# 2    2640.066402      -52.780981            -52.780981            -52.780981
# 3    2640.575382      -53.778382            -53.778382            -53.778382
# 4    2642.102322      -62.776237            -62.776237            -62.776237
# ..           ...             ...                   ...                   ...
# 995  4487.785343      -27.616689            -27.616689            -27.616689
# 996  4490.562222      -27.736083            -27.736083            -27.736083
# 997  4498.892859      -33.974690            -33.974690            -33.974690
# 998  4501.669738      -30.845896            -30.845896            -30.845896
# 999  4504.446617      -33.099520            -33.099520            -33.099520
#
#         weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0     2639.048443      -47.465765            -47.465765            -47.465765
# 1     2639.557423      -50.886612            -50.886612            -50.886612
# 2     2640.066402      -52.780981            -52.780981            -52.780981
# 3     2640.575382      -53.778382            -53.778382            -53.778382
# 4     2642.102322      -62.776237            -62.776237            -62.776237
# ...           ...             ...                   ...                   ...
# 1009  4532.215409     -136.539401           -136.539401           -136.539401
# 1010  4534.992288     -138.497705           -138.497705           -138.497705
# 1011  4537.769167      -53.394430            -53.394430            -53.394430
# 1012  4540.546046      -51.461377            -51.461377            -51.461377
# 1013  4543.322926      -54.860613            -54.860613            -54.860613
#
#          weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0     27.012407     27.012407     27.012407 -74.478172    -74.478172
# 1     25.586482     25.586482     25.586482 -76.473094    -76.473094
# 2     25.692803     25.692803     25.692803 -78.473784    -78.473784
# 3     26.668713     26.668713     26.668713 -80.447095    -80.447095
# 4     23.078664     23.078664     23.078664 -85.854901    -85.854901
# ...         ...           ...           ...        ...           ...
# 1009 -64.019536    -64.019536    -64.019536 -72.519864    -72.519864
# 1010 -64.019533    -64.019533    -64.019533 -74.478172    -74.478172
# 1011  23.078664     23.078664     23.078664 -76.473094    -76.473094
# 1012  27.012407     27.012407     27.012407 -78.473784    -78.473784
# 1013  25.586482     25.586482     25.586482 -80.447095    -80.447095
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0       -74.478172                   0.0                         0.0
# 1       -76.473094                   0.0                         0.0
# 2       -78.473784                   0.0                         0.0
# 3       -80.447095                   0.0                         0.0
# 4       -85.854901                   0.0                         0.0
# ...            ...                   ...                         ...
# 1009    -72.519864                   0.0                         0.0
# 1010    -74.478172                   0.0                         0.0
# 1011    -76.473094                   0.0                         0.0
# 1012    -78.473784                   0.0                         0.0
# 1013    -80.447095                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 0                            0.0  2591.582678
# 1                            0.0  2588.670811
# 2                            0.0  2587.285422
# 3                            0.0  2586.797001
# 4                            0.0  2579.326084
# ...                          ...          ...
# 1009                         0.0  4395.676008
# 1010                         0.0  4396.494584
# 1011                         0.0  4484.374737
# 1012                         0.0  4489.084669
# 1013                         0.0  4488.462313
#
# [1014 rows x 19 columns]

# %%
forecastc['yhat']
# Out:
# 0       2591.582678
# 1       2588.670811
# 2       2587.285422
# 3       2586.797001
# 4       2579.326084
#            ...
# 1009    4395.676008
# 1010    4396.494584
# 1011    4484.374737
# 1012    4489.084669
# 1013    4488.462313
# Name: yhat, Length: 1014, dtype: float64

# %%
forecastl['yhat']
# Out:
# 0       2591.582678
# 1       2588.670811
# 2       2587.285422
# 3       2586.797001
# 4       2579.326084
#            ...
# 1009    4395.676008
# 1010    4396.494584
# 1011    4484.374737
# 1012    4489.084669
# 1013    4488.462313
# Name: yhat, Length: 1014, dtype: float64

# %%
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mc = Prophet()
mc.fit(dfhc)
future = mc.make_future_dataframe(periods=14)
futureh = mc.make_future_dataframe(periods=14)
futurel = mc.make_future_dataframe(periods=14)
forecastc = mc.predict(future)
forecasth = mc.predict(mc.predict(futureh.merge(dfhh, how='left')))
forecastl = mc.predict(mc.predict(futurel.merge(dfhl, how='left')))
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
# Out:
# <ipython-input-63-577090b88df7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-63-577090b88df7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet()
ml = Prophet()
mc = Prophet()
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
futurecl = mc.make_future_dataframe(periods=14)
futurech = mc.make_future_dataframe(periods=14)
futurelc = mc.make_future_dataframe(periods=14)
futurehc = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
forecastch = mh.predict(futurech)
forecastcl = ml.predict(futurecl)
forecasthc = mc.predict(futurehc)
forecastlc = mc.predict(futurelc)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.plot(forecastch['ds'], forecastch['yhat'], label='최대대비종가예측')
plt.plot(forecastcl['ds'], forecastcl['yhat'], label='최소대비종가예측')
plt.plot(forecasthc['ds'], forecasthc['yhat'], label='종가대비최대예측')
plt.plot(forecastlc['ds'], forecastlc['yhat'], label='종가대비최소예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.plot(forecastch['ds'][-50-14:], forecastch['yhat'][-50-14:], label='최대대비종가예측')
plt.plot(forecastcl['ds'][-50-14:], forecastcl['yhat'][-50-14:], label='최소대비종가예측')
plt.plot(forecasthc['ds'][-50-14:], forecasthc['yhat'][-50-14:], label='종가대비최대예측')
plt.plot(forecastlc['ds'][-50-14:], forecastlc['yhat'][-50-14:], label='종가대비최소예측')
plt.legend()
plt.show()
# Out:
# <ipython-input-44-e1e183f06ba2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-44-e1e183f06ba2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dft[100:]
# Out:
#               Close     Open     High      Low  Volume  Change  ndays_high  \
# Date
# 2018-03-13  2765.31  2792.31  2801.90  2758.68     0.0 -0.0064     2872.87
# 2018-03-14  2749.48  2774.06  2777.11  2744.38     0.0 -0.0057     2872.87
# 2018-03-15  2747.33  2754.27  2763.03  2741.47     0.0 -0.0008     2872.87
# 2018-03-16  2752.01  2750.57  2761.85  2749.97     0.0  0.0017     2872.87
# 2018-03-19  2712.92  2741.38  2741.38  2694.59     0.0 -0.0142     2872.87
# ...             ...      ...      ...      ...     ...     ...         ...
# 2021-09-30  4307.54  4370.67  4382.55  4306.24     0.0 -0.0119     4545.85
# 2021-10-01  4357.05  4317.16  4375.19  4288.52     0.0  0.0115     4545.85
# 2021-10-04  4300.46  4348.84  4355.51  4278.94     0.0 -0.0130     4545.85
# 2021-10-05  4345.72  4309.87  4369.23  4309.87     0.0  0.0105     4545.85
# 2021-10-06  4363.55  4319.57  4365.57  4290.49     0.0  0.0041     4545.85
#
#             ndays_low
# Date
# 2018-03-13    2532.69
# 2018-03-14    2532.69
# 2018-03-15    2532.69
# 2018-03-16    2532.69
# 2018-03-19    2532.69
# ...               ...
# 2021-09-30    4305.91
# 2021-10-01    4288.52
# 2021-10-04    4278.94
# 2021-10-05    4278.94
# 2021-10-06    4278.94
#
# [900 rows x 8 columns]

# %%
forecastch['yhat']
# Out:
# 0       2547.566760
# 1       2548.770773
# 2       2550.787280
# 3       2552.776524
# 4       2556.598262
#            ...
# 1009    4535.473767
# 1010    4536.853049
# 1011    4564.038862
# 1012    4566.383091
# 1013    4568.179259
# Name: yhat, Length: 1014, dtype: float64

# %%
forecasthc['yhat']
# Out:
# 0       2591.582678
# 1       2588.670811
# 2       2587.285422
# 3       2586.797001
# 4       2579.326084
#            ...
# 1009    4395.676008
# 1010    4396.494584
# 1011    4484.374737
# 1012    4489.084669
# 1013    4488.462313
# Name: yhat, Length: 1014, dtype: float64

# %%
forecasth['yhat']
# Out:
# 0       2547.566760
# 1       2548.770773
# 2       2550.787280
# 3       2552.776524
# 4       2556.598262
#            ...
# 1009    4535.473767
# 1010    4536.853049
# 1011    4564.038862
# 1012    4566.383091
# 1013    4568.179259
# Name: yhat, Length: 1014, dtype: float64

# %%
(forecastch['yhat']!=forecasthc['yhat']).count()
# Out:
# 1014

# %%
from prophet import Prophet
pp = Prophet()
pp.fit(dfhh)
fth = pp.make_future_dataframe(periods=14)
pred = pp.predict(fth)

pp.fit(dfhh)
fth = pp.make_future_dataframe(periods=14)
pred = pp.predict(fth)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-27-f163007cfde2> in <module>
#       5 pred = pp.predict(fth)
#       6
# ----> 7 pp.fit(dfhh)
#       8 fth = pp.make_future_dataframe(periods=14)
#       9 pred = pp.predict(fth)
#
# C:\ProgramData\Anaconda3\lib\site-packages\prophet\forecaster.py in fit(self, df, **kwargs)
#    1102         """
#    1103         if self.history is not None:
# -> 1104             raise Exception('Prophet object can only be fit once. '
#    1105                             'Instantiate a new object.')
#    1106         if ('ds' not in df) or ('y' not in df):
#
# Exception: Prophet object can only be fit once. Instantiate a new object.

# %%
pp.predict(futurel)['yhat'] != forecastl['yhat']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1009    True
# 1010    True
# 1011    True
# 1012    True
# 1013    True
# Name: yhat, Length: 1014, dtype: bool

# %%
forecasth['yhat'] == pred['ds']

# %%
pred['yhat'].where(forecasth['yhat'] != pred['yhat']).count()
# Out:
# 0

# %%
(forecasth['ds'] == pred['ds']).where(True).count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f59a767ccac2> in <module>
# ----> 1 (forecasth['ds'] == pred['ds']).where(True).count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9284         """
#    9285         other = com.apply_if_callable(other, self)
# -> 9286         return self._where(
#    9287             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    9288         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9024                 cond = np.asanyarray(cond)
#    9025             if cond.shape != self.shape:
# -> 9026                 raise ValueError("Array conditional must be same shape as self")
#    9027             cond = self._constructor(cond, **self._construct_axes_dict())
#    9028
#
# ValueError: Array conditional must be same shape as self

# %%
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
pred = run_prophet(dfhh)
# Out:
# <ipython-input-9-172dabcff8d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-9-172dabcff8d9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-172dabcff8d9> in <module>
#       6 dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
#       7 dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
# ----> 8 pred = run_prophet(dfhh)
#
# <ipython-input-8-b1168d43c066> in run_prophet(timeserie, periods)
#       4     forecast = model.make_future_dataframe(periods=periods, include_history=False)
#       5     forecast = model.predict(forecast)
# ----> 6     return np.append(forecast['ds'].values.transpose(),forecast['yhat'].values.transpose())
#       7
#       8 # from multiprocessing import Pool, cpu_count
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in append(arr, values, axis)
#    4669         values = ravel(values)
#    4670         axis = arr.ndim-1
# -> 4671     return concatenate((arr, values), axis=axis)
#    4672
#    4673
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: invalid type promotion

# %%
pred

# %%
timeseries = {
    1:dfhh, 2:dfhl, 3:dfhc
}

# %%
timeseries.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
timeseries = {
    1:dfhh#, 2:dfhl, 3:dfhc
}

def get_timeserie(id):
    return timeseries[id]
#     return (timeseries[id], 14, True)

def run_prophet(id):
    return run_prophet(id, 14, True)
    
def run_prophet(id, periods=14, include_history=False):
    timeserie = get_timeserie(id)
    model = Prophet(uncertainty_samples=False)
    model.fit(timeserie)
    forecast = model.make_future_dataframe(periods=periods, include_history=include_history)
    forecast = model.predict(forecast)
    return np.append(np.array([id]),forecast['yhat'].values.transpose())
#     return forecast

# from multiprocessing import Pool, cpu_count
# print(f'Parallelism on {cpu_count()} CPU')
# with Pool(cpu_count()) as p:
#     predictions  = list(p.map(run_prophet, list(timeseries.keys())))

# %%
from multiprocessing import Pool, cpu_count
from tqdm import tqdm
# p = Pool(cpu_count())
p = Pool(1)
predictions = list(tqdm(p.imap(run_prophet, timeseries.keys()), total=len(timeseries.keys())))
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]

# %%
list(timeseries.keys())
# Out:
# [1]

# %%
run_prophet
# Out:
# <function __main__.run_prophet(id, periods=14, include_history=True)>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3c890c1545c1> in <module>
#       3 # p = Pool(cpu_count())
#       4 p = Pool(1)
# ----> 5 tqdm(p.imap(run_prophet, [1]))
#
# NameError: name 'run_prophet' is not defined

# %%
from multiprocessing import Pool, cpu_count
print(f'Parallelism on {cpu_count()} CPU')
with Pool(1) as p:
    predictions  = list(p.map(run_prophet, [(1)]))
# Out:
# Parallelism on 16 CPU

# %%
len(list(d))
# Out:
# 1015

# %%
np = run_prophet('DJI')
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e7753e12e36c> in <module>
# ----> 1 np = run_prophet('DJI')
#
# <ipython-input-19-1ccb0aa81b3f> in run_prophet(id, periods, include_history)
#      10     forecast = model.make_future_dataframe(periods=periods, include_history=include_history)
#      11     forecast = model.predict(forecast)
# ---> 12     return np.append(np.array([id]),forecast['yhat'].values.transpose())
#      13 #     return forecast
#      14
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'array'

# %%
np
# Out:
#            ds         trend  additive_terms      weekly      yearly  \
# 0  2021-10-07  36218.056429     -397.115480  137.739546 -534.855026
# 1  2021-10-08  36236.197388     -416.332556  138.004965 -554.337521
# 2  2021-10-09  36254.338347     -903.404750 -329.440765 -573.963985
# 3  2021-10-10  36272.479305     -922.982589 -329.440808 -593.541781
# 4  2021-10-11  36290.620264     -482.316289  130.555455 -612.871744
# 5  2021-10-12  36308.761222     -506.537101  125.216482 -631.753583
# 6  2021-10-13  36326.902181     -522.626143  127.365125 -649.991268
# 7  2021-10-14  36345.043140     -529.658705  137.739546 -667.398251
# 8  2021-10-15  36363.184098     -545.797374  138.004965 -683.802339
# 9  2021-10-16  36381.325057    -1028.490863 -329.440765 -699.050098
# 10 2021-10-17  36399.466016    -1042.451455 -329.440808 -713.010647
# 11 2021-10-18  36417.606974     -595.023280  130.555455 -725.578735
# 12 2021-10-19  36435.747933     -611.460536  125.216482 -736.677018
# 13 2021-10-20  36453.888892     -618.892354  127.365125 -746.257479
#
#     multiplicative_terms          yhat
# 0                    0.0  35820.940949
# 1                    0.0  35819.864832
# 2                    0.0  35350.933597
# 3                    0.0  35349.496716
# 4                    0.0  35808.303975
# 5                    0.0  35802.224122
# 6                    0.0  35804.276038
# 7                    0.0  35815.384435
# 8                    0.0  35817.386725
# 9                    0.0  35352.834194
# 10                   0.0  35357.014560
# 11                   0.0  35822.583694
# 12                   0.0  35824.287397
# 13                   0.0  35834.996538

# %%
forecasth[-14:]
# Out:
#              ds         trend  additive_terms      weekly      yearly  \
# 1000 2021-10-07  36218.056429     -397.115480  137.739546 -534.855026
# 1001 2021-10-08  36236.197388     -416.332556  138.004965 -554.337521
# 1002 2021-10-09  36254.338347     -903.404750 -329.440765 -573.963985
# 1003 2021-10-10  36272.479305     -922.982589 -329.440808 -593.541781
# 1004 2021-10-11  36290.620264     -482.316289  130.555455 -612.871744
# 1005 2021-10-12  36308.761222     -506.537101  125.216482 -631.753583
# 1006 2021-10-13  36326.902181     -522.626143  127.365125 -649.991268
# 1007 2021-10-14  36345.043140     -529.658705  137.739546 -667.398251
# 1008 2021-10-15  36363.184098     -545.797374  138.004965 -683.802339
# 1009 2021-10-16  36381.325057    -1028.490863 -329.440765 -699.050098
# 1010 2021-10-17  36399.466016    -1042.451455 -329.440808 -713.010647
# 1011 2021-10-18  36417.606974     -595.023280  130.555455 -725.578735
# 1012 2021-10-19  36435.747933     -611.460536  125.216482 -736.677018
# 1013 2021-10-20  36453.888892     -618.892354  127.365125 -746.257479
#
#       multiplicative_terms          yhat
# 1000                   0.0  35820.940949
# 1001                   0.0  35819.864832
# 1002                   0.0  35350.933597
# 1003                   0.0  35349.496716
# 1004                   0.0  35808.303975
# 1005                   0.0  35802.224122
# 1006                   0.0  35804.276038
# 1007                   0.0  35815.384435
# 1008                   0.0  35817.386725
# 1009                   0.0  35352.834194
# 1010                   0.0  35357.014560
# 1011                   0.0  35822.583694
# 1012                   0.0  35824.287397
# 1013                   0.0  35834.996538

# %%
def run_prophet(dataframe, periods=14):

# %%
dji = fdr.DataReader('DJI', '2015')
dft = dji[-1000:]
n = 50
dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
dfh = pd.DataFrame(dft.sort_index().reset_index(), columns=['Date', 'Close', 'ndays_high', 'ndays_low'])
dfhh = dfh.rename(columns = {'Date':'ds', 'ndays_high':'y'})
dfhl = dfh.rename(columns = {'Date':'ds', 'ndays_low':'y'})
dfhc = dfh.rename(columns = {'Date':'ds', 'Close':'y'})
from prophet import Prophet
mh = Prophet(uncertainty_samples=False)
ml = Prophet(uncertainty_samples=False)
mc = Prophet(uncertainty_samples=False)
mh.fit(dfhh)
ml.fit(dfhl)
mc.fit(dfhc)
futurel = ml.make_future_dataframe(periods=14, include_history=False)
futureh = mh.make_future_dataframe(periods=14)
futurec = mc.make_future_dataframe(periods=14)
forecasth = mh.predict(futureh)
forecastl = ml.predict(futurel)
forecastc = mc.predict(futurec)
plt.subplot(211)
plt.plot(dfh['Date'], dfh['Close'], label='실제종가')
plt.plot(forecasth['ds'], forecasth['yhat'], label='최대예측')
plt.plot(forecastl['ds'], forecastl['yhat'], label='최소예측')
plt.plot(forecastc['ds'], forecastc['yhat'], label='종가예측')
plt.legend()
plt.subplot(212)
plt.plot(dfh['Date'][-50:], dfh['Close'][-50:], label='실제종가')
plt.plot(forecasth['ds'][-50-14:], forecasth['yhat'][-50-14:], label='최대예측')
plt.plot(forecastl['ds'][-50-14:], forecastl['yhat'][-50-14:], label='최소예측')
plt.plot(forecastc['ds'][-50-14:], forecastc['yhat'][-50-14:], label='종가예측')
plt.legend()
plt.show()
# Out:
# <ipython-input-2-62f4903ef7e8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_high'] = dft['High'].rolling(window=n, min_periods=1).max()
# <ipython-input-2-62f4903ef7e8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['ndays_low'] = dft['Low'].rolling(window=n, min_periods=1).min()
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
